# %% [markdown]
# # Center of Gravity for Central Network

# %% [markdown]
# # Geo-Locations
#
# The geo-locations of sites can be found in CSV format extracted from SCGX import files.

# %%
# !wget https://raw.githubusercontent.com/robogeekcanada/miscellaneous/main/Geo_location_sites_CSV.csv
# Out:
# --2023-02-24 18:13:58--  https://raw.githubusercontent.com/robogeekcanada/miscellaneous/main/Geo_location_sites_CSV.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8337 (8.1K) [text/plain]
# Saving to: ‘Geo_location_sites_CSV.csv’
#
# Geo_location_sites_ 100%[===================>]   8.14K  --.-KB/s    in 0s
#
# 2023-02-24 18:13:58 (58.3 MB/s) - ‘Geo_location_sites_CSV.csv’ saved [8337/8337]

# %% [markdown]
# Using Pandas to load the data, display first 10.

# %%
import pandas as pd

data = pd.read_csv(r'Geo_location_sites_CSV.csv')
df = pd.DataFrame(data, columns=['SiteID', 'Name', 'Address', 'City', 'State', 'Country', 'Postal Code', 'Latitude', 'Longitude'])
df[:10].style
# Out:
# <style type="text/css">
# </style>
# <table id="T_c7c27_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >SiteID</th>
#       <th class="col_heading level0 col1" >Name</th>
#       <th class="col_heading level0 col2" >Address</th>
#       <th class="col_heading level0 col3" >City</th>
#       <th class="col_heading level0 col4" >State</th>
#       <th class="col_heading level0 col5" >Country</th>
#       <th class="col_heading level0 col6" >Postal Code</th>
#       <th class="col_heading level0 col7" >Latitude</th>
#       <th class="col_heading level0 col8" >Longitude</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7c27_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c7c27_row0_col0" class="data row0 col0" >23350</td>
#       <td id="T_c7c27_row0_col1" class="data row0 col1" >P_CC_Cent_ON_Y001_Brampton</td>
#       <td id="T_c7c27_row0_col2" class="data row0 col2" >15 Westcreek Blvd.</td>
#       <td id="T_c7c27_row0_col3" class="data row0 col3" >Brampton</td>
#       <td id="T_c7c27_row0_col4" class="data row0 col4" >ON</td>
#       <td id="T_c7c27_row0_col5" class="data row0 col5" >Canada</td>
#       <td id="T_c7c27_row0_col6" class="data row0 col6" >L6T 5T4</td>
#       <td id="T_c7c27_row0_col7" class="data row0 col7" >43.684400</td>
#       <td id="T_c7c27_row0_col8" class="data row0 col8" >-79.702700</td>
#     </tr>
#     <tr>
#       <th id="T_c7c27_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c7c27_row1_col0" class="data row1 col0" >23351</td>
#       <td id="T_c7c27_row1_col1" class="data row1 col1" >P_CC_West_AB_Y002_Calgary</td>
#       <td id="T_c7c27_row1_col2" class="data row1 col2" >3852 23rd Street NE</td>
#       <td id="T_c7c27_row1_col3" class="data row1 col3" >Calgary</td>
#       <td id="T_c7c27_row1_col4" class="data row1 col4" >AB</td>
#       <td id="T_c7c27_row1_col5" class="data row1 col5" >Canada</td>
#       <td id="T_c7c27_row1_col6" class="data row1 col6" >T2E 6T2</td>
#       <td id="T_c7c27_row1_col7" class="data row1 col7" >51.086700</td>
#       <td id="T_c7c27_row1_col8" class="data row1 col8" >-114.006200</td>
#     </tr>
#     <tr>
#       <th id="T_c7c27_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c7c27_row2_col0" class="data row2 col0" >23352</td>
#       <td id="T_c7c27_row2_col1" class="data row2 col1" >P_CO_Cent_ON_Y058_YAYA  Foods</td>
#       <td id="T_c7c27_row2_col2" class="data row2 col2" >450b Kipling Avenue</td>
#       <td id="T_c7c27_row2_col3" class="data row2 col3" >Etobicoke</td>
#       <td id="T_c7c27_row2_col4" class="data row2 col4" >ON</td>
#       <td id="T_c7c27_row2_col5" class="data row2 col5" >Canada</td>
#       <td id="T_c7c27_row2_col6" class="data row2 col6" >M8Z 5E1</td>
#       <td id="T_c7c27_row2_col7" class="data row2 col7" >43.608500</td>
#       <td id="T_c7c27_row2_col8" class="data row2 col8" >-79.522100</td>
#     </tr>
#     <tr>
#       <th id="T_c7c27_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c7c27_row3_col0" class="data row3 col0" >23353</td>
#       <td id="T_c7c27_row3_col1" class="data row3 col1" >P_CO_Cent_ON_Y059_Joriki</td>
#       <td id="T_c7c27_row3_col2" class="data row3 col2" >3431 McNicoll Ave</td>
#       <td id="T_c7c27_row3_col3" class="data row3 col3" >Scarborough</td>
#       <td id="T_c7c27_row3_col4" class="data row3 col4" >ON</td>
#       <td id="T_c7c27_row3_col5" class="data row3 col5" >Canada</td>
#       <td id="T_c7c27_row3_col6" class="data row3 col6" >M1V 2V3</td>
#       <td id="T_c7c27_row3_col7" class="data row3 col7" >43.821700</td>
#       <td id="T_c7c27_row3_col8" class="data row3 col8" >-79.256000</td>
#     </tr>
#     <tr>
#       <th id="T_c7c27_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c7c27_row4_col0" class="data row4 col0" >23354</td>
#       <td id="T_c7c27_row4_col1" class="data row4 col1" >P_CO_Cent_ON_Y057_Delta Beverages</td>
#       <td id="T_c7c27_row4_col2" class="data row4 col2" >21 Marycroft Ave</td>
#       <td id="T_c7c27_row4_col3" class="data row4 col3" >Woodbridge</td>
#       <td id="T_c7c27_row4_col4" class="data row4 col4" >ON</td>
#       <td id="T_c7c27_row4_col5" class="data row4 col5" >Canada</td>
#       <td id="T_c7c27_row4_col6" class="data row4 col6" >L4L 5Y6</td>
#       <td id="T_c7c27_row4_col7" class="data row4 col7" >43.780600</td>
#       <td id="T_c7c27_row4_col8" class="data row4 col8" >-79.563500</td>
#     </tr>
#     <tr>
#       <th id="T_c7c27_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c7c27_row5_col0" class="data row5 col0" >23355</td>
#       <td id="T_c7c27_row5_col1" class="data row5 col1" >P_CO_Cent_ON_XXXX_CottCentral</td>
#       <td id="T_c7c27_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_c7c27_row5_col3" class="data row5 col3" >Mississauga</td>
#       <td id="T_c7c27_row5_col4" class="data row5 col4" >ON</td>
#       <td id="T_c7c27_row5_col5" class="data row5 col5" >Canada</td>
#       <td id="T_c7c27_row5_col6" class="data row5 col6" >L4V 1H6</td>
#       <td id="T_c7c27_row5_col7" class="data row5 col7" >43.694500</td>
#       <td id="T_c7c27_row5_col8" class="data row5 col8" >-79.626300</td>
#     </tr>
#     <tr>
#       <th id="T_c7c27_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c7c27_row6_col0" class="data row6 col0" >23356</td>
#       <td id="T_c7c27_row6_col1" class="data row6 col1" >P_CO_West_AB_WWWW_CottWest</td>
#       <td id="T_c7c27_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_c7c27_row6_col3" class="data row6 col3" >Calgary</td>
#       <td id="T_c7c27_row6_col4" class="data row6 col4" >AB</td>
#       <td id="T_c7c27_row6_col5" class="data row6 col5" >Canada</td>
#       <td id="T_c7c27_row6_col6" class="data row6 col6" >T2C 2V2</td>
#       <td id="T_c7c27_row6_col7" class="data row6 col7" >50.985650</td>
#       <td id="T_c7c27_row6_col8" class="data row6 col8" >-113.964100</td>
#     </tr>
#     <tr>
#       <th id="T_c7c27_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c7c27_row7_col0" class="data row7 col0" >23357</td>
#       <td id="T_c7c27_row7_col1" class="data row7 col1" >P_CO_Cent_ON_Y060_Alliance</td>
#       <td id="T_c7c27_row7_col2" class="data row7 col2" >201 Speers Road</td>
#       <td id="T_c7c27_row7_col3" class="data row7 col3" >Oakville</td>
#       <td id="T_c7c27_row7_col4" class="data row7 col4" >ON</td>
#       <td id="T_c7c27_row7_col5" class="data row7 col5" >Canada</td>
#       <td id="T_c7c27_row7_col6" class="data row7 col6" >L6K 2E8</td>
#       <td id="T_c7c27_row7_col7" class="data row7 col7" >43.444900</td>
#       <td id="T_c7c27_row7_col8" class="data row7 col8" >-79.689400</td>
#     </tr>
#     <tr>
#       <th id="T_c7c27_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c7c27_row8_col0" class="data row8 col0" >23358</td>
#       <td id="T_c7c27_row8_col1" class="data row8 col1" >P_CO_West_AB_Y061_X-Treme</td>
#       <td id="T_c7c27_row8_col2" class="data row8 col2" >7910 - 51st Street S.E. </td>
#       <td id="T_c7c27_row8_col3" class="data row8 col3" >Calgary</td>
#       <td id="T_c7c27_row8_col4" class="data row8 col4" >AB</td>
#       <td id="T_c7c27_row8_col5" class="data row8 col5" >Canada</td>
#       <td id="T_c7c27_row8_col6" class="data row8 col6" >T2C 4R2</td>
#       <td id="T_c7c27_row8_col7" class="data row8 col7" >50.982900</td>
#       <td id="T_c7c27_row8_col8" class="data row8 col8" >-113.959800</td>
#     </tr>
#     <tr>
#       <th id="T_c7c27_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c7c27_row9_col0" class="data row9 col0" >23359</td>
#       <td id="T_c7c27_row9_col1" class="data row9 col1" >P_CO_West_BC_YC02_LMBCArea</td>
#       <td id="T_c7c27_row9_col2" class="data row9 col2" >nan</td>
#       <td id="T_c7c27_row9_col3" class="data row9 col3" >Richmond</td>
#       <td id="T_c7c27_row9_col4" class="data row9 col4" >BC</td>
#       <td id="T_c7c27_row9_col5" class="data row9 col5" >Canada</td>
#       <td id="T_c7c27_row9_col6" class="data row9 col6" >V6V 2B8<

# %% [markdown]
# ### Decoding **Name** values
#
# Main challenge **Name** values are composed of a string that determines the type of building, the location type, state/province, site number and site name and full address including latitude and longitude
#
# The **Name** values need to be broken down to help queries later on.
#
# The following functions return the type of site, type of location, the region the site belongs, the site number and the site name.

# %%
def find_type(name):

  if name[0] == 'P':
    return 'Production'
  elif name[0] == 'W':
    return 'Warehouse'

def find_location_type(name):

  if name[2:4] == 'CC':
    return 'Combo Center'
  elif name[2:4] == 'PL':
    return 'Plant'
  elif name[2:4] == 'CO':
    return 'Co-Packer'
  elif name[2:4] == 'PG':
    return 'Purchased Goods'

  elif name[2:4] == 'DB':
    return 'Double Button' 
  elif name[2:4] == 'DC':
    return 'Distribution Center' 
  elif name[2:4] == 'OS':
    return 'Outside Storage' 
  elif name[2:4] == 'XD':
    return 'Cross Dock' 
  elif name[2:4] == 'PT':
    return 'Port' 

def find_region(name):

    if name[5:9] == 'Cent':
      return 'Central'
    elif name[5:9] == 'East':
      return 'East'
    elif name[5:9] == 'West':
      return 'West'
    elif name[5:9] == 'Misc':
      return 'Miscellaneous'

def find_number(name):
  return name[13:17]

def find_site_name(name):
  return name[18:]

# %% [markdown]
# ### Example of using Decoding **Name** values
#
# In this simple example we sort through the Name of all the sites and decode the first 10.

# %%
for name in df['Name'][:10]:

  print(name + ' is a ' + find_type(name) + ' '+ find_location_type(name) +
        ' located in the ' + find_region(name) + ' region with designation ' + find_number(name)+ " " +
        find_site_name(name))
# Out:
# P_CC_Cent_ON_Y001_Brampton is a Production Combo Center located in the Central region with designation Y001 Brampton
# P_CC_West_AB_Y002_Calgary is a Production Combo Center located in the West region with designation Y002 Calgary
# P_CO_Cent_ON_Y058_YAYA  Foods is a Production Co-Packer located in the Central region with designation Y058 YAYA  Foods
# P_CO_Cent_ON_Y059_Joriki is a Production Co-Packer located in the Central region with designation Y059 Joriki
# P_CO_Cent_ON_Y057_Delta Beverages is a Production Co-Packer located in the Central region with designation Y057 Delta Beverages
# P_CO_Cent_ON_XXXX_CottCentral is a Production Co-Packer located in the Central region with designation XXXX CottCentral
# P_CO_West_AB_WWWW_CottWest is a Production Co-Packer located in the West region with designation WWWW CottWest
# P_CO_Cent_ON_Y060_Alliance is a Production Co-Packer located in the Central region with designation Y060 Alliance
# P_CO_West_AB_Y061_X-Treme is a Production Co-Packer located in the West region with designation Y061 X-Treme
# P_CO_West_BC_YC02_LMBCArea is a Production Co-Packer located in the West region with designation YC02 LMBCArea

# %% [markdown]
# ## Adding columns to the Header
#
# The dataframe **df** contains the following columns: *SiteID, Name, Address, City, State, Country, Postal Code, Latitude and Longitude*

# %%
print(df.columns.values)
# Out:
# ['SiteID' 'Name' 'Address' 'City' 'State' 'Country' 'Postal Code'
#  'Latitude' 'Longitude']

# %% [markdown]
# We will add the following columns to the header: *LocationType, CenterType, SiteName, Region and SiteNumber*, these new columns will be inserted after *SiteID*

# %%
header = list(df.columns.values)
header.remove('Name')

extended_info = ['LocationType', 'CenterType', 'SiteName', 'Region', 'SiteNumber']

#insert the extended info to the header
header[1:1] = extended_info
header
# Out:
# ['SiteID',
#  'LocationType',
#  'CenterType',
#  'SiteName',
#  'Region',
#  'SiteNumber',
#  'Address',
#  'City',
#  'State',
#  'Country',
#  'Postal Code',
#  'Latitude',
#  'Longitude']

# %% [markdown]
# ## Extracting data from each data row

# %% [markdown]
# ### Example
#
# The following example shows how to use **iloc** method to extract the values.

# %%
print(df.iloc[0][0])
print(df.iloc[0][1])
# Out:
# 23350
# P_CC_Cent_ON_Y001_Brampton

# %% [markdown]
# ### Finding info for the site
#
# The **find_site_info()** function takes the row index as an input and outputs all the row data.

# %%
def find_site_info(index):

  site_id = df.iloc[index][0]
  location_type = find_type(df.iloc[index][1])
  center_type = find_location_type(df.iloc[index][1])
  site_name = find_site_name(df.iloc[index][1])
  region = find_region(df.iloc[index][1])
  site_number = find_number(df.iloc[index][1])
  address = df.iloc[index][2]
  city = df.iloc[index][3]
  state = df.iloc[index][4]
  country = df.iloc[index][5]
  postal_code = df.iloc[index][6]
  latitude = df.iloc[index][7]
  longitude = df.iloc[index][8]

  site_data = [site_id, location_type, center_type, site_name, region, site_number, address, 
              city, state, country, postal_code, latitude, longitude]
  return site_data

find_site_info(0)
# Out:
# [23350,
#  'Production',
#  'Combo Center',
#  'Brampton',
#  'Central',
#  'Y001',
#  '15 Westcreek Blvd.',
#  'Brampton',
#  'ON',
#  'Canada',
#  'L6T 5T4',
#  43.6844,
#  -79.7027]

# %% [markdown]
# ### Example
#
# Store all data in an array called **sites_data** by looping through the entire table. In this example we show the first 2 rows.

# %%
sites_data = []

for i in range(len(df.index)):
  sites_data.append(find_site_info(i))

sites_data[:2]
# Out:
# [[23350,
#   'Production',
#   'Combo Center',
#   'Brampton',
#   'Central',
#   'Y001',
#   '15 Westcreek Blvd.',
#   'Brampton',
#   'ON',
#   'Canada',
#   'L6T 5T4',
#   43.6844,
#   -79.7027],
#  [23351,
#   'Production',
#   'Combo Center',
#   'Calgary',
#   'West',
#   'Y002',
#   '3852 23rd Street NE',
#   'Calgary',
#   'AB',
#   'Canada',
#   'T2E 6T2',
#   51.0867,
#   -114.0062]]

# %% [markdown]
# ## Saving CSV file
#
# The **sites_data** array we created previously we will store in a CSV file called **sites_data.csv**. However we first need to add the *header* array we modified earliear.

# %%
import csv

with open('sites_data.csv', 'w', encoding='UTF8', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerows(sites_data)

# %% [markdown]
# ### Example
#
# Now let's load the **sites_data.csv** to a dataframe called **revised_data**
# In this example we will display the first 10.

# %%
revised_data = pd.read_csv(r'sites_data.csv')
revised_data[:10].style
# Out:
# <style type="text/css">
# </style>
# <table id="T_4195a_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >SiteID</th>
#       <th class="col_heading level0 col1" >LocationType</th>
#       <th class="col_heading level0 col2" >CenterType</th>
#       <th class="col_heading level0 col3" >SiteName</th>
#       <th class="col_heading level0 col4" >Region</th>
#       <th class="col_heading level0 col5" >SiteNumber</th>
#       <th class="col_heading level0 col6" >Address</th>
#       <th class="col_heading level0 col7" >City</th>
#       <th class="col_heading level0 col8" >State</th>
#       <th class="col_heading level0 col9" >Country</th>
#       <th class="col_heading level0 col10" >Postal Code</th>
#       <th class="col_heading level0 col11" >Latitude</th>
#       <th class="col_heading level0 col12" >Longitude</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4195a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4195a_row0_col0" class="data row0 col0" >23350</td>
#       <td id="T_4195a_row0_col1" class="data row0 col1" >Production</td>
#       <td id="T_4195a_row0_col2" class="data row0 col2" >Combo Center</td>
#       <td id="T_4195a_row0_col3" class="data row0 col3" >Brampton</td>
#       <td id="T_4195a_row0_col4" class="data row0 col4" >Central</td>
#       <td id="T_4195a_row0_col5" class="data row0 col5" >Y001</td>
#       <td id="T_4195a_row0_col6" class="data row0 col6" >15 Westcreek Blvd.</td>
#       <td id="T_4195a_row0_col7" class="data row0 col7" >Brampton</td>
#       <td id="T_4195a_row0_col8" class="data row0 col8" >ON</td>
#       <td id="T_4195a_row0_col9" class="data row0 col9" >Canada</td>
#       <td id="T_4195a_row0_col10" class="data row0 col10" >L6T 5T4</td>
#       <td id="T_4195a_row0_col11" class="data row0 col11" >43.684400</td>
#       <td id="T_4195a_row0_col12" class="data row0 col12" >-79.702700</td>
#     </tr>
#     <tr>
#       <th id="T_4195a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4195a_row1_col0" class="data row1 col0" >23351</td>
#       <td id="T_4195a_row1_col1" class="data row1 col1" >Production</td>
#       <td id="T_4195a_row1_col2" class="data row1 col2" >Combo Center</td>
#       <td id="T_4195a_row1_col3" class="data row1 col3" >Calgary</td>
#       <td id="T_4195a_row1_col4" class="data row1 col4" >West</td>
#       <td id="T_4195a_row1_col5" class="data row1 col5" >Y002</td>
#       <td id="T_4195a_row1_col6" class="data row1 col6" >3852 23rd Street NE</td>
#       <td id="T_4195a_row1_col7" class="data row1 col7" >Calgary</td>
#       <td id="T_4195a_row1_col8" class="data row1 col8" >AB</td>
#       <td id="T_4195a_row1_col9" class="data row1 col9" >Canada</td>
#       <td id="T_4195a_row1_col10" class="data row1 col10" >T2E 6T2</td>
#       <td id="T_4195a_row1_col11" class="data row1 col11" >51.086700</td>
#       <td id="T_4195a_row1_col12" class="data row1 col12" >-114.006200</td>
#     </tr>
#     <tr>
#       <th id="T_4195a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4195a_row2_col0" class="data row2 col0" >23352</td>
#       <td id="T_4195a_row2_col1" class="data row2 col1" >Production</td>
#       <td id="T_4195a_row2_col2" class="data row2 col2" >Co-Packer</td>
#       <td id="T_4195a_row2_col3" class="data row2 col3" >YAYA  Foods</td>
#       <td id="T_4195a_row2_col4" class="data row2 col4" >Central</td>
#       <td id="T_4195a_row2_col5" class="data row2 col5" >Y058</td>
#       <td id="T_4195a_row2_col6" class="data row2 col6" >450b Kipling Avenue</td>
#       <td id="T_4195a_row2_col7" class="data row2 col7" >Etobicoke</td>
#       <td id="T_4195a_row2_col8" class="data row2 col8" >ON</td>
#       <td id="T_4195a_row2_col9" class="data row2 col9" >Canada</td>
#       <td id="T_4195a_row2_col10" class="data row2 col10" >M8Z 5E1</td>
#       <td id="T_4195a_row2_col11" class="data row2 col11" >43.608500</td>
#       <td id="T_4195a_row2_col12" class="data row2 col12" >-79.522100</td>
#     </tr>
#     <tr>
#       <th id="T_4195a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4195a_row3_col0" class="data row3 col0" >23353</td>
#       <td id="T_4195a_row3_col1" class="data row3 col1" >Production</td>
#       <td id="T_4195a_row3_col2" class="data row3 col2" >Co-Packer</td>
#       <td id="T_4195a_row3_col3" class="data row3 col3" >Joriki</td>
#       <td id="T_4195a_row3_col4" class="data row3 col4" >Central</td>
#       <td id="T_4195a_row3_col5" class="data row3 col5" >Y059</td>
#       <td id="T_4195a_row3_col6" class="data row3 col6" >3431 McNicoll Ave</td>
#       <td id="T_4195a_row3_col7" class="data row3 col7" >Scarborough</td>
#       <td id="T_4195a_row3_col8" class="data row3 col8" >ON</td>
#       <td id="T_4195a_row3_col9" class="data row3 col9" >Canada</td>
#       <td id="T_4195a_row3_col10" class="data row3 col10" >M1V 2V3</td>
#       <td id="T_4195a_row3_col11" class="data row3 col11" >43.821700</td>
#       <td id="T_4195a_row3_col12" class="data row3 col12" >-79.256000</td>
#     </tr>
#     <tr>
#       <th id="T_4195a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4195a_row4_col0" class="data row4 col0" >23354</td>
#       <td id="T_4195a_row4_col1" class="data row4 col1" >Production</td>
#       <td id="T_4195a_row4_col2" class="data row4 col2" >Co-Packer</td>
#       <td id="T_4195a_row4_col3" class="data row4 col3" >Delta Beverages</td>
#       <td id="T_4195a_row4_col4" class="data row4 col4" >Central</td>
#       <td id="T_4195a_row4_col5" class="data row4 col5" >Y057</td>
#       <td id="T_4195a_row4_col6" class="data row4 col6" >21 Marycroft Ave</td>
#       <td id="T_4195a_row4_col7" class="data row4 col7" >Woodbridge</td>
#       <td id="T_4195a_row4_col8" class="data row4 col8" >ON</td>
#       <td id="T_4195a_row4_col9" class="data row4 col9" >Canada</td>
#       <td id="T_4195a_row4_col10" class="data row4 col10" >L4L 5Y6</td>
#       <td id="T_4195a_row4_col11" class="data row4 col11" >43.780600</td>
#       <td id="T_4195a_row4_col12" class="data row4 col12" >-79.563500</td>
#     </tr>
#     <tr>
#       <th id="T_4195a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4195a_row5_col0" class="data row5 col0" >23355</td>
#       <td id="T_4195a_row5_col1" class="data row5 col1" >Production</td>
#       <td id="T_4195a_row5_col2" class="data row5 col2" >Co-Packer</td>
#       <td id="T_4195a_row5_col3" class="data row5 col3" >CottCentral</td>
#       <td id="T_4195a_row5_col4" class="data row5 col4" >Central</td>
#       <td id="T_4195a_row5_col5" class="data row5 col5" >XXXX</td>
#       <td id="T_4195a_row5_col6" class="data row5 col6" >0</td>
#       <td id="T_4195a_row5_col7" class="data row5 col7" >Mississauga</td>
#       <td id="T_4195a_row5_col8" class="data row5 col8" >ON</td>
#       <td id="T_4195a_row5_col9" class="data row5 col9" >Canada</td>
#       <td id="T_4195a_row5_col10" class="data row5 col10" >L4V 1H6</td>
#       <td id="T_4195a_row5_col11" class="data row5 col11" >43.694500</td>
#       <td id="T_4195a_row5_col12" class="data row5 col12" >-79.626300</td>
#     </tr>
#     <tr>
#       <th id="T_4195a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4195a_row6_col0" class="data row6 col0" >23356</td>
#       <td id="T_4195a_row6_col1" class="data row6 col1" >Production</td>
#       <td id="T_4195a_row6_col2" class="data row6 col2" >Co-Packer</td>
#       <td id="T_4195a_row6_col3" class="data row6 col3" >CottWest</td>
#       <td id="T_4195a_row6_col4" class="data row6 col4" >West</td>
#       <td id="T_4195a_row6_col5" class="data row6 col5" >WWWW</td>
#       <td id="T_4195a_row6_col6" class="data row6 col6" >0</td>
#       <td id="T_4195a_row6_col7" class="data row6 col7" >Calgary</td>
#       <td id="T_4195a_row6_col8" class="data row6 col8" >AB</td>
#       <td id="T_4195a_row6_col9" class="data row6 col9" >Canada</td>
#       <td id="T_4195a_row6_col10" class="data row6 col10" >T2C 2V2</td>
#       <td id="T_4195a_row6_col11" class="data row6 col11" >50.985650</td>
#       <td id="T_4195a_row6_col12" clas

# %% [markdown]
# ## Plotting a Map
#
# Using **plotly** library to display locations in a map.
#
# For more information on **plotly**:
#
# https://plotly.com/python-api-reference/generated/plotly.express.scatter_geo.html
#
# https://plotly.com/python/scattermapbox/

# %%
# import the plotly express
import plotly.express as px

# set up the chart from the df dataFrame
fig = px.scatter_geo(revised_data, 
                     # longitude is taken from the revised_data["Longitude"] columns and latitude from revised_data["Latitude"]
                     lon="Longitude", 
                     lat="Latitude", 
                     # choose the map chart's projection
                     projection="natural earth",
                     # columns which is in bold in the pop up
                     hover_name = "SiteName",
                     # format of the popup not to display these columns' data
                     hover_data = {"SiteNumber": True,  
                                   "SiteID":False,
                                   "LocationType": False,
                                   "CenterType": False,
                                   "Region": False,
                                   "Address": False,
                                   "City": False,
                                   "State": False,
                                   "Postal Code": False                                                                    
                                     }
                     )

fig.update_traces(marker=dict(size=5, color="red"))

# fit the map to surround the points
fig.update_geos(fitbounds="locations", showcountries = True)

# add title
fig.update_layout(title = 'Coke Canada sites')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="5910d49a-dedc-4a6b-9004-68c13be63ea4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5910d49a-dedc-4a6b-9004-68c13be63ea4")) {                    Plotly.newPlot(                        "5910d49a-dedc-4a6b-9004-68c13be63ea4",                        [{"customdata":[["Y001",23350,"Production","Combo Center","Central","15 Westcreek Blvd.","Brampton","ON","L6T 5T4"],["Y002",23351,"Production","Combo Center","West","3852 23rd Street NE","Calgary","AB","T2E 6T2"],["Y058",23352,"Production","Co-Packer","Central","450b Kipling Avenue","Etobicoke","ON","M8Z 5E1"],["Y059",23353,"Production","Co-Packer","Central","3431 McNicoll Ave","Scarborough","ON","M1V 2V3"],["Y057",23354,"Production","Co-Packer","Central","21 Marycroft Ave","Woodbridge","ON","L4L 5Y6"],["XXXX",23355,"Production","Co-Packer","Central","0","Mississauga","ON","L4V 1H6"],["WWWW",23356,"Production","Co-Packer","West","0","Calgary","AB","T2C 2V2"],["Y060",23357,"Production","Co-Packer","Central","201 Speers Road","Oakville","ON","L6K 2E8"],["Y061",23358,"Production","Co-Packer","West","7910 - 51st Street S.E. ","Calgary","AB","T2C 4R2"],["YC02",23359,"Production","Co-Packer","West",null,"Richmond","BC","V6V 2B8"],["YC02",23360,"Production","Co-Packer","West",null,"Calgary","AB","T2C 2V2"],["ZZZZ",23362,"Production","Purchased Goods","Miscellaneous","0","Atlanta","GA","30336"],["Y011",23363,"Production","Plant","Central","24 Fenmar Dr","Toronto(Weston)","ON","M9L 1L8"],["Y028",23364,"Production","Plant","East","1515. 46e avenue","Lachine","QC","H8T 2N8"],["Y045",23365,"Production","Plant","West","2471 Viking Way","Richmond","BC","V6V 1N3"],["Y008",23366,"Warehouse","Double Button","Central","1795 23rd Street East","Owen Sound","ON","N4K 5N5"],["Y009",23367,"Warehouse","Double Button","Central","987 Great Northern Rd.","Sault Ste Marie","ON","P6B 0B9"],["Y012",23368,"Warehouse","Cross Dock","Central","3215 Electricity Dr","Windsor","ON","N8W 5J1"],["Y014",23369,"Warehouse","Cross Dock","East","500 Blvd de L'Acadie","Edmundston  ","NB","E3V 3L1"],["Y015",23370,"Warehouse","Double Button","East","225 Allison Blvd","Fredericton  ","NB","E3C 2S5"],["Y017",23371,"Warehouse","Double Button","East","28 McIlveen Drive, Unit #28","Saint John","NB","E2J 4Y7"],["Y018",23372,"Warehouse","Double Button","East","7165 Cambrooken Court","Coldbrook","NS","B4R 1A2"],["Y020",23373,"Warehouse","Double Button","East","101 MacGregor Avenue","Stellarton  ","NS","B0K 2A0"],["Y022",23374,"Warehouse","Double Button","East","310 Prince Place","Truro","NS","B2N 1C9"],["Y023",23375,"Warehouse","Double Button","East","345 Highway #1, Unit #3","Yarmouth ","NS","B5A 1E7"],["Y025",23376,"Warehouse","Cross Dock","East","2 Aviation Ave","Winsloe","PE","C1E 1Z2"],["Y032",23377,"Warehouse","Double Button","East","8500 boul. Indstriel","Trois-Rivi\u00e8res","QC","G9A 5E1"],["Y036",23378,"Warehouse","Double Button","West","44520 Yale Road","Sardis","BC","V2R 1A9"],["Y050",23380,"Warehouse","Cross Dock","West","4502-35 Avenue","Lloydminster","SK","S9V 0Y4"],["Y004",23381,"Warehouse","Distribution Center","Central","401 Bayview Drive","Barrie ","ON","L4N 8Y2"],["Y001",23382,"Warehouse","Distribution Center","Central","15 Westcreek Blvd.","Brampton","ON","L6T 5T4"],["Y006",23383,"Warehouse","Distribution Center","Central","800 Innovation Dr","Kingston","ON","K7K 7E7"],["Y010",23384,"Warehouse","Distribution Center","Central","970 Lorne St.","Sudbury","ON","P3C 4R9"],["Y005",23385,"Warehouse","Distribution Center","Central","1575 Barton St E","Hamilton","ON","L8H 7K6"],["Y007",23386,"Warehouse","Distribution Center","Central","950 Green Valley Rd","London","ON","N6N 1E3"],["Y016",23387,"Warehouse","Distribution Center","East ...

# %% [markdown]
# ## Using queries
#
# We can perform queries on the dataframe **revised_data**. For example let's look at all the sites that are located in the *Central region*.

# %%
central_sites = revised_data.query("Region == 'Central'")
central_sites
# Out:
#     SiteID LocationType           CenterType         SiteName   Region  \
# 0    23350   Production         Combo Center         Brampton  Central
# 2    23352   Production            Co-Packer      YAYA  Foods  Central
# 3    23353   Production            Co-Packer           Joriki  Central
# 4    23354   Production            Co-Packer  Delta Beverages  Central
# 5    23355   Production            Co-Packer      CottCentral  Central
# 7    23357   Production            Co-Packer         Alliance  Central
# 12   23363   Production                Plant           Weston  Central
# 15   23366    Warehouse        Double Button       Owen Sound  Central
# 16   23367    Warehouse        Double Button  Sault Ste Marie  Central
# 17   23368    Warehouse           Cross Dock          Windsor  Central
# 29   23381    Warehouse  Distribution Center           Barrie  Central
# 30   23382    Warehouse  Distribution Center       BramptonDC  Central
# 31   23383    Warehouse  Distribution Center         Kingston  Central
# 32   23384    Warehouse  Distribution Center          Sudbury  Central
# 33   23385    Warehouse  Distribution Center         Hamilton  Central
# 34   23386    Warehouse  Distribution Center           London  Central
# 57   23411    Warehouse      Outside Storage          Toronto  Central
#
#    SiteNumber                 Address             City State Country  \
# 0        Y001      15 Westcreek Blvd.         Brampton    ON  Canada
# 2        Y058     450b Kipling Avenue        Etobicoke    ON  Canada
# 3        Y059       3431 McNicoll Ave      Scarborough    ON  Canada
# 4        Y057        21 Marycroft Ave       Woodbridge    ON  Canada
# 5        XXXX                       0      Mississauga    ON  Canada
# 7        Y060         201 Speers Road         Oakville    ON  Canada
# 12       Y011            24 Fenmar Dr  Toronto(Weston)    ON  Canada
# 15       Y008   1795 23rd Street East       Owen Sound    ON  Canada
# 16       Y009  987 Great Northern Rd.  Sault Ste Marie    ON  Canada
# 17       Y012     3215 Electricity Dr          Windsor    ON  Canada
# 29       Y004       401 Bayview Drive          Barrie     ON  Canada
# 30       Y001      15 Westcreek Blvd.         Brampton    ON  Canada
# 31       Y006       800 Innovation Dr         Kingston    ON  Canada
# 32       Y010           970 Lorne St.          Sudbury    ON  Canada
# 33       Y005        1575 Barton St E         Hamilton    ON  Canada
# 34       Y007     950 Green Valley Rd           London    ON  Canada
# 57       Y053      225 Carrier  Drive        Etobicoke    ON  Canada
#
#    Postal Code   Latitude  Longitude
# 0      L6T 5T4  43.684400 -79.702700
# 2      M8Z 5E1  43.608500 -79.522100
# 3      M1V 2V3  43.821700 -79.256000
# 4      L4L 5Y6  43.780600 -79.563500
# 5      L4V 1H6  43.694500 -79.626300
# 7      L6K 2E8  43.444900 -79.689400
# 12     M9L 1L8  43.759800 -79.536800
# 15     N4K 5N5  44.586080 -80.914940
# 16     P6B 0B9  46.547600 -84.327000
# 17     N8W 5J1  42.284500 -82.965600
# 29     L4N 8Y2  44.340400 -79.677600
# 30     L6T 5T4  43.684400 -79.702700
# 31     K7K 7E7  44.274197 -76.439718
# 32     P3C 4R9  46.473300 -81.025400
# 33     L8H 7K6  43.242900 -79.808600
# 34     N6N 1E3  42.922700 -81.198900
# 57     M9W 5Y8  43.748100 -79.620400

# %% [markdown]
# ### Example
#
# An example of using a function to plot maps from the query using other map settings.

# %%
def display_map(region):

  query_string = 'Region == ' + "'" + region + "'"

  sites = revised_data.query(query_string)

  fig = px.scatter_geo(sites, 
                      # longitude is taken from the revised_data["Longitude"] columns and latitude from revised_data["Latitude"]
                      lon="Longitude", 
                      lat="Latitude", 
                      # choose the map chart's projection
                      projection="natural earth",
                      # columns which is in bold in the pop up
                      hover_name = "SiteName",
                      # format of the popup not to display these columns' data
                      hover_data = {"SiteNumber": True,  
                                    "SiteID":False,
                                    "LocationType": False,
                                    "CenterType": False,
                                    "Region": False,
                                    "Address": False,
                                    "City": False,
                                    "State": False,
                                    "Postal Code": False                                                                    
                                      }
                      )

  fig.update_traces(marker=dict(size=15, color="red"))

  # fit the map to surround the points
  fig.update_geos(fitbounds="locations", showcountries = True)

  fig.update_geos(
    resolution=50,
    showcoastlines=True, coastlinecolor="RebeccaPurple",
    showland=True, landcolor="LightGreen",
    showocean=True, oceancolor="LightBlue",
    showlakes=True, lakecolor="Blue",
    showrivers=True, rivercolor="Blue"
  )


  # add title
  fig.update_layout(title = query_string)
  fig.show()

display_map('Central')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="60fc50e6-3845-402f-83cc-c35d56aee21d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("60fc50e6-3845-402f-83cc-c35d56aee21d")) {                    Plotly.newPlot(                        "60fc50e6-3845-402f-83cc-c35d56aee21d",                        [{"customdata":[["Y001",23350,"Production","Combo Center","Central","15 Westcreek Blvd.","Brampton","ON","L6T 5T4"],["Y058",23352,"Production","Co-Packer","Central","450b Kipling Avenue","Etobicoke","ON","M8Z 5E1"],["Y059",23353,"Production","Co-Packer","Central","3431 McNicoll Ave","Scarborough","ON","M1V 2V3"],["Y057",23354,"Production","Co-Packer","Central","21 Marycroft Ave","Woodbridge","ON","L4L 5Y6"],["XXXX",23355,"Production","Co-Packer","Central","0","Mississauga","ON","L4V 1H6"],["Y060",23357,"Production","Co-Packer","Central","201 Speers Road","Oakville","ON","L6K 2E8"],["Y011",23363,"Production","Plant","Central","24 Fenmar Dr","Toronto(Weston)","ON","M9L 1L8"],["Y008",23366,"Warehouse","Double Button","Central","1795 23rd Street East","Owen Sound","ON","N4K 5N5"],["Y009",23367,"Warehouse","Double Button","Central","987 Great Northern Rd.","Sault Ste Marie","ON","P6B 0B9"],["Y012",23368,"Warehouse","Cross Dock","Central","3215 Electricity Dr","Windsor","ON","N8W 5J1"],["Y004",23381,"Warehouse","Distribution Center","Central","401 Bayview Drive","Barrie ","ON","L4N 8Y2"],["Y001",23382,"Warehouse","Distribution Center","Central","15 Westcreek Blvd.","Brampton","ON","L6T 5T4"],["Y006",23383,"Warehouse","Distribution Center","Central","800 Innovation Dr","Kingston","ON","K7K 7E7"],["Y010",23384,"Warehouse","Distribution Center","Central","970 Lorne St.","Sudbury","ON","P3C 4R9"],["Y005",23385,"Warehouse","Distribution Center","Central","1575 Barton St E","Hamilton","ON","L8H 7K6"],["Y007",23386,"Warehouse","Distribution Center","Central","950 Green Valley Rd","London","ON","N6N 1E3"],["Y053",23411,"Warehouse","Outside Storage","Central","225 Carrier  Drive","Etobicoke","ON","M9W 5Y8"]],"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>Latitude=%{lat}<br>Longitude=%{lon}<br>SiteNumber=%{customdata[0]}<extra></extra>","hovertext":["Brampton","YAYA  Foods","Joriki","Delta Beverages","CottCentral","Alliance","Weston","Owen Sound","Sault Ste Marie","Windsor","Barrie","BramptonDC","Kingston","Sudbury","Hamilton","London","Toronto"],"lat":[43.6844,43.6085,43.8217,43.7806,43.6945,43.4449,43.7598,44.58608,46.5476,42.2845,44.3404,43.6844,44.274197,46.4733,43.2429,42.9227,43.7481],"legendgroup":"","lon":[-79.7027,-79.5221,-79.256,-79.5635,-79.6263,-79.6894,-79.5368,-80.91494,-84.327,-82.9656,-79.6776,-79.7027,-76.439718,-81.0254,-79.8086,-81.1989,-79.6204],"marker":{"color":"red","symbol":"circle","size":15},"mode":"markers","name":"","showlegend":false,"type":"scattergeo"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.44444444444444 ...

# %% [markdown]
# # Understanding Demand
#
# Let's start by downloading the demand from each site and for sourcing sites the volume they produced.

# %%
# !wget https://raw.githubusercontent.com/robogeekcanada/miscellaneous/main/demand_CSV.csv
# Out:
# --2023-02-24 18:26:06--  https://raw.githubusercontent.com/robogeekcanada/miscellaneous/main/demand_CSV.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 47782 (47K) [text/plain]
# Saving to: ‘demand_CSV.csv’
#
# demand_CSV.csv      100%[===================>]  46.66K  --.-KB/s    in 0.007s
#
# 2023-02-24 18:26:06 (6.49 MB/s) - ‘demand_CSV.csv’ saved [47782/47782]

# %% [markdown]
# ## Demand Data
#
# Let's create a dataframe named **demand_data** and display the first 10 rows.

# %%
demand_data = pd.read_csv(r'demand_CSV.csv')
demand_data[:10].style
# Out:
# <style type="text/css">
# </style>
# <table id="T_29b84_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Demand_Location</th>
#       <th class="col_heading level0 col1" >Demand_Site</th>
#       <th class="col_heading level0 col2" > Total_Demand </th>
#       <th class="col_heading level0 col3" >Source_Location</th>
#       <th class="col_heading level0 col4" >Source_Site</th>
#       <th class="col_heading level0 col5" >First_Warehouse</th>
#       <th class="col_heading level0 col6" >First_Stop</th>
#       <th class="col_heading level0 col7" >Second_Warehouse</th>
#       <th class="col_heading level0 col8" >Second_Stop</th>
#       <th class="col_heading level0 col9" >Third_Warehouse</th>
#       <th class="col_heading level0 col10" >Third_Stop</th>
#       <th class="col_heading level0 col11" >Product_Details</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_29b84_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_29b84_row0_col0" class="data row0 col0" >Y001 Brampton, ON DC</td>
#       <td id="T_29b84_row0_col1" class="data row0 col1" >Y001</td>
#       <td id="T_29b84_row0_col2" class="data row0 col2" > 23,564,663 </td>
#       <td id="T_29b84_row0_col3" class="data row0 col3" >Y001 Brampton, ON DC</td>
#       <td id="T_29b84_row0_col4" class="data row0 col4" >Y001</td>
#       <td id="T_29b84_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_29b84_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_29b84_row0_col7" class="data row0 col7" >nan</td>
#       <td id="T_29b84_row0_col8" class="data row0 col8" >nan</td>
#       <td id="T_29b84_row0_col9" class="data row0 col9" >nan</td>
#       <td id="T_29b84_row0_col10" class="data row0 col10" >nan</td>
#       <td id="T_29b84_row0_col11" class="data row0 col11" >Brampton PET, Core Cans, BIB, 300ml, 250ml, Dasani</td>
#     </tr>
#     <tr>
#       <th id="T_29b84_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_29b84_row1_col0" class="data row1 col0" >Y001 Brampton, ON DC</td>
#       <td id="T_29b84_row1_col1" class="data row1 col1" >Y001</td>
#       <td id="T_29b84_row1_col2" class="data row1 col2" > 734,805 </td>
#       <td id="T_29b84_row1_col3" class="data row1 col3" >Y002 Calgary, AB DC</td>
#       <td id="T_29b84_row1_col4" class="data row1 col4" >Y002</td>
#       <td id="T_29b84_row1_col5" class="data row1 col5" >Y071 TCS Calgary, AB DC</td>
#       <td id="T_29b84_row1_col6" class="data row1 col6" >Y071</td>
#       <td id="T_29b84_row1_col7" class="data row1 col7" >Y053 NFI Toronto Aux WH</td>
#       <td id="T_29b84_row1_col8" class="data row1 col8" >Y053</td>
#       <td id="T_29b84_row1_col9" class="data row1 col9" >nan</td>
#       <td id="T_29b84_row1_col10" class="data row1 col10" >nan</td>
#       <td id="T_29b84_row1_col11" class="data row1 col11" >355ml Can Fresca and Diet A&W</td>
#     </tr>
#     <tr>
#       <th id="T_29b84_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_29b84_row2_col0" class="data row2 col0" >Y001 Brampton, ON DC</td>
#       <td id="T_29b84_row2_col1" class="data row2 col1" >Y001</td>
#       <td id="T_29b84_row2_col2" class="data row2 col2" > 33,868 </td>
#       <td id="T_29b84_row2_col3" class="data row2 col3" >Y002 Calgary, AB DC</td>
#       <td id="T_29b84_row2_col4" class="data row2 col4" >Y002</td>
#       <td id="T_29b84_row2_col5" class="data row2 col5" >Y071 TCS Calgary, AB DC</td>
#       <td id="T_29b84_row2_col6" class="data row2 col6" >Y071</td>
#       <td id="T_29b84_row2_col7" class="data row2 col7" >Y053 NFI Toronto Aux WH</td>
#       <td id="T_29b84_row2_col8" class="data row2 col8" >Y053</td>
#       <td id="T_29b84_row2_col9" class="data row2 col9" >nan</td>
#       <td id="T_29b84_row2_col10" class="data row2 col10" >nan</td>
#       <td id="T_29b84_row2_col11" class="data row2 col11" >1L AHA</td>
#     </tr>
#     <tr>
#       <th id="T_29b84_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_29b84_row3_col0" class="data row3 col0" >Y001 Brampton, ON DC</td>
#       <td id="T_29b84_row3_col1" class="data row3 col1" >Y001</td>
#       <td id="T_29b84_row3_col2" class="data row3 col2" > 3,414 </td>
#       <td id="T_29b84_row3_col3" class="data row3 col3" >Y002 Calgary, AB DC</td>
#       <td id="T_29b84_row3_col4" class="data row3 col4" >Y002</td>
#       <td id="T_29b84_row3_col5" class="data row3 col5" >nan</td>
#       <td id="T_29b84_row3_col6" class="data row3 col6" >nan</td>
#       <td id="T_29b84_row3_col7" class="data row3 col7" >nan</td>
#       <td id="T_29b84_row3_col8" class="data row3 col8" >nan</td>
#       <td id="T_29b84_row3_col9" class="data row3 col9" >nan</td>
#       <td id="T_29b84_row3_col10" class="data row3 col10" >nan</td>
#       <td id="T_29b84_row3_col11" class="data row3 col11" >10L BIB skus</td>
#     </tr>
#     <tr>
#       <th id="T_29b84_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_29b84_row4_col0" class="data row4 col0" >Y001 Brampton, ON DC</td>
#       <td id="T_29b84_row4_col1" class="data row4 col1" >Y001</td>
#       <td id="T_29b84_row4_col2" class="data row4 col2" > 12,622,135 </td>
#       <td id="T_29b84_row4_col3" class="data row4 col3" >Y011 Weston, ON DC</td>
#       <td id="T_29b84_row4_col4" class="data row4 col4" >Y011</td>
#       <td id="T_29b84_row4_col5" class="data row4 col5" >Y053 NFI Toronto Aux WH</td>
#       <td id="T_29b84_row4_col6" class="data row4 col6" >Y053</td>
#       <td id="T_29b84_row4_col7" class="data row4 col7" >nan</td>
#       <td id="T_29b84_row4_col8" class="data row4 col8" >nan</td>
#       <td id="T_29b84_row4_col9" class="data row4 col9" >nan</td>
#       <td id="T_29b84_row4_col10" class="data row4 col10" >nan</td>
#       <td id="T_29b84_row4_col11" class="data row4 col11" >All Weston can SKUS - hotfill can, monster, non core SSD</td>
#     </tr>
#     <tr>
#       <th id="T_29b84_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_29b84_row5_col0" class="data row5 col0" >Y001 Brampton, ON DC</td>
#       <td id="T_29b84_row5_col1" class="data row5 col1" >Y001</td>
#       <td id="T_29b84_row5_col2" class="data row5 col2" > 128,499 </td>
#       <td id="T_29b84_row5_col3" class="data row5 col3" >Y028 Lachine, QC PC</td>
#       <td id="T_29b84_row5_col4" class="data row5 col4" >Y028</td>
#       <td id="T_29b84_row5_col5" class="data row5 col5" >Y053 NFI Toronto Aux WH</td>
#       <td id="T_29b84_row5_col6" class="data row5 col6" >Y053</td>
#       <td id="T_29b84_row5_col7" class="data row5 col7" >nan</td>
#       <td id="T_29b84_row5_col8" class="data row5 col8" >nan</td>
#       <td id="T_29b84_row5_col9" class="data row5 col9" >nan</td>
#       <td id="T_29b84_row5_col10" class="data row5 col10" >nan</td>
#       <td id="T_29b84_row5_col11" class="data row5 col11" >500ml PET small runners</td>
#     </tr>
#     <tr>
#       <th id="T_29b84_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_29b84_row6_col0" class="data row6 col0" >Y001 Brampton, ON DC</td>
#       <td id="T_29b84_row6_col1" class="data row6 col1" >Y001</td>
#       <td id="T_29b84_row6_col2" class="data row6 col2" > 1,883,011 </td>
#       <td id="T_29b84_row6_col3" class="data row6 col3" >Y057 Delta Beverages </td>
#       <td id="T_29b84_row6_col4" class="data row6 col4" >Y057</td>
#       <td id="T_29b84_row6_col5" class="data row6 col5" >Y053 NFI Toronto Aux WH</td>
#       <td id="T_29b84_row6_col6" class="data row6 col6" >Y053</td>
#       <td id="T_29b84_row6_col7" class="data row6 col7" >nan</td>
#       <td id="T_29b84_row6_col8" class="data row6 col8" >nan</td>
#       <td id="T_29b84_row6_col9" class="data row6 col9" >nan</td>
#       <td id="T_29b84_row6_col10" class="data row6 col10" >nan</td>
#       <td id="T_29b84_row6_col11" class="data row6 col11" >Juice, PA, Glass</td>
#     </tr>
#     <tr>
#       <th id="T_29b84_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_29b84_row7_col0" class="data row7 col0" >Y001 Brampton, ON DC</td>
#       <td id="T_29b84_row7_col1" class="data row7 col1" >Y001</td>
#       <td

# %% [markdown]
# ### Example
#
# Pull demand data for Brampton location using a query.

# %%
brampton_volume = demand_data.query("Demand_Site == 'Y001'")
brampton_volume
# Out:
#          Demand_Location Demand_Site  Total_Demand         Source_Location  \
# 0   Y001 Brampton, ON DC        Y001    23,564,663    Y001 Brampton, ON DC
# 1   Y001 Brampton, ON DC        Y001       734,805     Y002 Calgary, AB DC
# 2   Y001 Brampton, ON DC        Y001        33,868     Y002 Calgary, AB DC
# 3   Y001 Brampton, ON DC        Y001         3,414     Y002 Calgary, AB DC
# 4   Y001 Brampton, ON DC        Y001    12,622,135      Y011 Weston, ON DC
# 5   Y001 Brampton, ON DC        Y001       128,499     Y028 Lachine, QC PC
# 6   Y001 Brampton, ON DC        Y001     1,883,011   Y057 Delta Beverages
# 7   Y001 Brampton, ON DC        Y001       726,501            Y059 Joriki
# 8   Y001 Brampton, ON DC        Y001       547,957    Y060 Alliance repack
# 9   Y001 Brampton, ON DC        Y001       351,905      External Purchases
# 10  Y001 Brampton, ON DC        Y001       517,933      External Purchases
#
#    Source_Site          First_Warehouse First_Stop         Second_Warehouse  \
# 0         Y001                      NaN        NaN                      NaN
# 1         Y002  Y071 TCS Calgary, AB DC       Y071  Y053 NFI Toronto Aux WH
# 2         Y002  Y071 TCS Calgary, AB DC       Y071  Y053 NFI Toronto Aux WH
# 3         Y002                      NaN        NaN                      NaN
# 4         Y011  Y053 NFI Toronto Aux WH       Y053                      NaN
# 5         Y028  Y053 NFI Toronto Aux WH       Y053                      NaN
# 6         Y057  Y053 NFI Toronto Aux WH       Y053                      NaN
# 7         Y059  Y053 NFI Toronto Aux WH       Y053                      NaN
# 8         Y060  Y053 NFI Toronto Aux WH       Y053                      NaN
# 9         Exte                      NaN        NaN                      NaN
# 10        Exte  Y053 NFI Toronto Aux WH       Y053                      NaN
#
#    Second_Stop Third_Warehouse Third_Stop  \
# 0          NaN             NaN        NaN
# 1         Y053             NaN        NaN
# 2         Y053             NaN        NaN
# 3          NaN             NaN        NaN
# 4          NaN             NaN        NaN
# 5          NaN             NaN        NaN
# 6          NaN             NaN        NaN
# 7          NaN             NaN        NaN
# 8          NaN             NaN        NaN
# 9          NaN             NaN        NaN
# 10         NaN             NaN        NaN
#
#                                       Product_Details
# 0   Brampton PET, Core Cans, BIB, 300ml, 250ml, Da...
# 1                       355ml Can Fresca and Diet A&W
# 2                                              1L AHA
# 3                                        10L BIB skus
# 4   All Weston can SKUS - hotfill can, monster, no...
# 5                             500ml PET small runners
# 6                                    Juice, PA, Glass
# 7                                                  VW
# 8                                       Variety Packs
# 9                                Smartwater, some BIB
# 10        Some Smartwater, CorePower, Monster Imports

# %% [markdown]
# ### Example: Adding Volume
#
# In this example let's take the output of the query and add the total demand.
# Notice that string manipulation is required to remove unnecessary commas.
#
# And also a conversion from string > float > int is required to add the demand from each source location

# %%
#brampton_volume[' Total_Demand ']

total_demand = 0

for demand in brampton_volume[' Total_Demand ']:

  demand = demand.strip()
  demand = demand.replace("," , "")

  #print(int(float(demand)))

  total_demand += int(float(demand))

print(f"{total_demand:,}")
# Out:
# 41,114,691

# %% [markdown]
# ### Example: Function to a site volume

# %%
def get_site_demand(site_number):

  query_string = "Demand_Site == " + "'" + site_number + "'"

  site_volume = demand_data.query(query_string)
  return site_volume

# %%
site_demand  = get_site_demand('Y001')

#site_volume  = get_site_volume(site_number)
total_demand = 0

for demand in site_demand[' Total_Demand ']:

  demand = demand.strip()
  demand = demand.replace("," , "")

  #print(int(float(demand)))

  total_demand += int(float(demand))

print(f"{total_demand:,}")
# Out:
# 41,114,691

# %% [markdown]
# ### Example: NFI volume
#
# Since there is no demand from NFI but it's used a first stop, then we can query as follows

# %%
nfi_volume = demand_data.query("First_Stop == 'Y053'")
nfi_volume
# Out:
#              Demand_Location Demand_Site  Total_Demand   \
# 4       Y001 Brampton, ON DC        Y001    12,622,135
# 5       Y001 Brampton, ON DC        Y001       128,499
# 6       Y001 Brampton, ON DC        Y001     1,883,011
# 7       Y001 Brampton, ON DC        Y001       726,501
# 8       Y001 Brampton, ON DC        Y001       547,957
# ..                       ...         ...            ...
# 371  Y071 TCS Calgary, AB DC        Y071           584
# 373  Y071 TCS Calgary, AB DC        Y071       240,731
# 374  Y071 TCS Calgary, AB DC        Y071        94,873
# 375  Y071 TCS Calgary, AB DC        Y071        67,040
# 376  Y071 TCS Calgary, AB DC        Y071         2,137
#
#            Source_Location Source_Site          First_Warehouse First_Stop  \
# 4       Y011 Weston, ON DC        Y011  Y053 NFI Toronto Aux WH       Y053
# 5      Y028 Lachine, QC PC        Y028  Y053 NFI Toronto Aux WH       Y053
# 6    Y057 Delta Beverages         Y057  Y053 NFI Toronto Aux WH       Y053
# 7             Y059 Joriki         Y059  Y053 NFI Toronto Aux WH       Y053
# 8     Y060 Alliance repack        Y060  Y053 NFI Toronto Aux WH       Y053
# ..                     ...         ...                      ...        ...
# 371    Y028 Lachine, QC PC        Y028  Y053 NFI Toronto Aux WH       Y053
# 373  Y057 Delta Beverages         Y057  Y053 NFI Toronto Aux WH       Y053
# 374           Y059 Joriki         Y059  Y053 NFI Toronto Aux WH       Y053
# 375   Y060 Alliance repack        Y060  Y053 NFI Toronto Aux WH       Y053
# 376     External Purchases        Exte  Y053 NFI Toronto Aux WH       Y053
#
#     Second_Warehouse Second_Stop Third_Warehouse Third_Stop  \
# 4                NaN         NaN             NaN        NaN
# 5                NaN         NaN             NaN        NaN
# 6                NaN         NaN             NaN        NaN
# 7                NaN         NaN             NaN        NaN
# 8                NaN         NaN             NaN        NaN
# ..               ...         ...             ...        ...
# 371              NaN         NaN             NaN        NaN
# 373              NaN         NaN             NaN        NaN
# 374              NaN         NaN             NaN        NaN
# 375              NaN         NaN             NaN        NaN
# 376              NaN         NaN             NaN        NaN
#
#                                        Product_Details
# 4    All Weston can SKUS - hotfill can, monster, no...
# 5                              500ml PET small runners
# 6                                     Juice, PA, Glass
# 7                                                   VW
# 8                                        Variety Packs
# ..                                                 ...
# 371                                    small 500ml PET
# 373                                       HF Juice, PA
# 374                                                 VW
# 375                                      Variety Packs
# 376                                          CorePower
#
# [228 rows x 12 columns]

# %% [markdown]
# Once we identified all the demand locations that require a first stop in NFI, then we can add this total volume as shown below.

# %%
total_volume = 0

for volume in nfi_volume[' Total_Demand ']:

  volume = volume.strip()
  volume = volume.replace("," , "")

  #print(int(float(demand)))

  total_volume += int(float(volume))

print(f"{total_volume:,}")
# Out:
# 69,746,509

# %% [markdown]
# ### Examples
#
# The following examples show how to get the total volumes for Weston, Barrie and Central

# %%
def get_sum_volume(site_vol):

  total_volume = 0

  for vol in site_vol[' Total_Demand ']:
    vol = vol.strip()
    vol = vol.replace("," , "")

    total_volume += int(float(vol))
  return total_volume
  #print(f"{total_volume:,}")

# %%
weston_volume = get_site_demand('Y011')
get_sum_volume(weston_volume)
# Out:
# 615752

# %%
barrie_volume = get_site_demand('Y004')
get_sum_volume(barrie_volume)
# Out:
# 8415218

# %% [markdown]
# Notice that NFI has zero demand as it's not a DC that distributes but an OS(Outside Storage) location

# %%
central_volume = ['Y001', 'Y011', 'Y004', 'Y005', 'Y006', 'Y007', 'Y010', 'Y024', 'Y053', 'Y054']

total_volume = 0

for volume in central_volume:
  
  vol = get_site_demand(volume)
  sum_vol = get_sum_volume(vol)
  print(f"{volume} {sum_vol :,} ")

  total_volume += sum_vol

print(f"total volume : {total_volume : ,}")
# Out:
# Y001 41,114,691
# Y011 615,752
# Y004 8,415,218
# Y005 8,142,142
# Y006 4,297,028
# Y007 10,456,162
# Y010 2,798,484
# Y024 7,861,575
# Y053 0
# Y054 1,074,646
# total volume :  84,775,698

# %% [markdown]
# # Putting all Together

# %% [markdown]
# ## Example:
#
# In this example we are looking for *(SiteNumber == 'Y001' and LocationType == 'Warehouse')* and find respective *latitude* and *longitude* in float format. Last example removes the empty spaces from *SiteName* values.

# %%
sites_data = pd.read_csv(r'sites_data.csv')

bramptonDC_data = sites_data.query("SiteNumber == 'Y001' and LocationType == 'Warehouse'")

bramptonDC_data
# Out:
#     SiteID LocationType           CenterType    SiteName   Region SiteNumber  \
# 30   23382    Warehouse  Distribution Center  BramptonDC  Central       Y001
#
#                Address      City State Country Postal Code  Latitude  \
# 30  15 Westcreek Blvd.  Brampton    ON  Canada     L6T 5T4   43.6844
#
#     Longitude
# 30   -79.7027

# %%
lon = float(bramptonDC_data['Longitude'])
lat = float(bramptonDC_data['Latitude'])

print(lat, lon)
# Out:
# 43.6844 -79.7027

# %%
str(bramptonDC_data['SiteName']).splitlines()[0][6:]
# Out:
# 'BramptonDC'

# %% [markdown]
# ## Central volumes with respective Lat & Long

# %%
#Excluding Pizza Pizza from Weston

locations = ['Y001', 'Y004', 'Y005', 'Y006', 'Y007', 'Y010', 'Y024', 'Y053', 'Y054']
sites_data = pd.read_csv(r'sites_data.csv')

total_volume = 0

for location in locations:
  
  vol = get_site_demand(location)
  sum_vol = get_sum_volume(vol)

  query_string = "SiteNumber == " + "'" + location + "' " + "and LocationType == 'Warehouse'"
  #print(query_string)
  siteDC_data = sites_data.query(query_string)

  lon = float(siteDC_data['Longitude'])
  lat = float(siteDC_data['Latitude'])
  site_name = str(siteDC_data['SiteName']).splitlines()[0][6:]

  print(f"{volume} {site_name} {sum_vol :,} {lat :} {lon :}")

  total_volume += sum_vol

print('\n')
print(f"total volume : {total_volume : ,}")
# Out:
# Y054 BramptonDC 41,114,691 43.6844 -79.7027
# Y054 Barrie 8,415,218 44.3404 -79.6776
# Y054 Hamilton 8,142,142 43.2429 -79.8086
# Y054 Kingston 4,297,028 44.274197 -76.439718
# Y054 London 10,456,162 42.9227 -81.1989
# Y054 Sudbury 2,798,484 46.4733 -81.0254
# Y054 Ottawa 7,861,575 45.3865 -75.6075
# Y054 Toronto 0 43.7481 -79.6204
# Y054 Thunder Bay 1,074,646 48.3774 -89.2997
#
#
# total volume :  84,159,946

# %% [markdown]
# # Calculation of MidPoint Center of Gravity

# %% [markdown]
# ## Summary
#
# The geographic midpoint is calculated by finding the center of gravity for the locations in the 'Your Places' list. The latitude and longitude for each location is converted into Cartesian (x,y,z) coordinates. The x,y, and z coordinates are then multiplied by the weighting factor and added together. A line can be drawn from the center of the earth out to this new x, y, z coordinate, and the point where the line intersects the surface of the earth is the geographic midpoint. This surface point is converted into the latitude and longitude for the midpoint.
#
# Reference: http://www.geomidpoint.com/calculation.html

# %% [markdown]
# ## Calculations procedure
#
# Given the values for the first location in the list:
#
# Lat1, lon1, years1, months1 and days
#
# 1. Convert Lat1 and Lon1 from degrees to radians.
#
#   $lat1 = lat1 * PI/180$
#
#   $lon1 = lon1 * PI/180$
#
# 2. Convert lat/lon to Cartesian coordinates for first location.
#
#   $X1 = cos(lat1) * cos(lon1)$
#
#   $Y1 = cos(lat1) * sin(lon1)$
#
#   $Z1 = sin(lat1)$
#
# 3. Compute weight (by time) for first location.
#
#   $w1= (years1 * 365.25) + (months1 * 30.4375) + days1$
#
# If locations are to be weighted equally, set w1, w2 etc all equal to 1.
#
# 4. Repeat steps 1-3 for all remaining locations in the list.
#
# 5. Compute combined total weight for all locations.
#   $Totweight = w1 + w2 + ... + wn$
#
# 6. Compute weighted average x, y and z coordinates.
#   $x = ((x1 * w1) + (x2 * w2) + ... + (xn * wn)) / totweight$
#   $y = ((y1 * w1) + (y2 * w2) + ... + (yn * wn)) / totweight$
#   $z = ((z1 * w1) + (z2 * w2) + ... + (zn * wn)) / totweight$
#
# 7. Convert average x, y, z coordinate to latitude and longitude. Note that in Excel and possibly some other applications, the parameters need to be reversed in the atan2 function, for example, use atan2(X,Y) instead of atan2(Y,X).
#
#   $Lon = atan2(y, x)$
#
#   $Hyp = sqrt(x * x + y * y)$
#
#   $Lat = atan2(z, hyp)$
#
# 8. Convert lat and lon to degrees.
#
#   $lat = lat * 180/PI$
#   $lon = lon * 180/PI$
#
# 9. Special case: If abs(x) < 10-9 and abs(y) < 10-9 and abs(z) < 10-9 then the geographic midpoint is the center of the earth.

# %% [markdown]
# ## Data upload
#
# The **center_gravity.csv** file includes the volume of NFI. Even though NFI is not a demand site, important to take into account for the Center of Gravity calculation.

# %%
# !wget https://raw.githubusercontent.com/robogeekcanada/miscellaneous/main/center_gravity.csv
# Out:
# --2023-02-24 18:58:10--  https://raw.githubusercontent.com/robogeekcanada/miscellaneous/main/center_gravity.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 415 [text/plain]
# Saving to: ‘center_gravity.csv.1’
#
# center_gravity.csv. 100%[===================>]     415  --.-KB/s    in 0s
#
# 2023-02-24 18:58:10 (19.7 MB/s) - ‘center_gravity.csv.1’ saved [415/415]

# %% [markdown]
# ### Data Preview

# %%
sites_data = pd.read_csv(r'center_gravity.csv')
sites_data
# Out:
#   SiteNumber     SiteName    Volume   Latitude   Longitude
# 0       Y001   BramptonDC  41114691  43.684400  -79.702700
# 1       Y004       Barrie   8415218  44.340400  -79.677600
# 2       Y005     Hamilton   8142142  43.242900  -79.808600
# 3       Y006     Kingston   4297028  44.274197  -76.439718
# 4       Y007       London  10456162  42.922700  -81.198900
# 5       Y010      Sudbury   2798484  46.473300  -81.025400
# 6       Y024       Ottawa   7861575  45.386500  -75.607500
# 7       Y053      Toronto  69746509  43.748100  -79.620400
# 8       Y054  Thunder Bay   1074646  48.377400  -89.299700

# %% [markdown]
# ### Calculations
#
# Working, it could be prettier.

# %%
#Convert to radians and X,Y,Z, steps 1 & 2

import math

x = 0
y = 0
z = 0

X = 0
Y = 0
Z = 0
total_vol = 0

for index in range(len(sites_data.index)):

  site_number = sites_data.iloc[index][0]
  site_name = sites_data.iloc[index][1]
  site_volume = sites_data.iloc[index][2]
  site_latitude = sites_data.iloc[index][3]
  site_longitude = sites_data.iloc[index][4]

  lat_rad = math.radians(site_latitude)
  long_rad = math.radians(site_longitude)

  x1 = math.cos(lat_rad)*math.cos(long_rad)
  y1 = math.cos(lat_rad)*math.sin(long_rad)
  z1 = math.sin(lat_rad)

  total_vol += site_volume
  X += x1*site_volume
  Y += y1*site_volume
  Z += z1*site_volume

  print(f"{site_number :} {site_name :} {site_volume : } {site_latitude :} {site_longitude :} {lat_rad :} {long_rad :} {x1 :} {y1 :} {z1 :}")


# Calculating center of gravity

x = X/total_vol
y = Y/total_vol
z = Z/total_vol

print(total_vol)

print(f"{x} {y} {z}")

Lon = math.atan2(y,x)
Hyp = math.sqrt(x**2 + y**2)
Lat = math.atan2(z, Hyp)

print(Lon, Hyp, Lat)

LAT = math.degrees(Lat)
LON = math.degrees(Lon)

print(LAT, LON)
# Out:
# Y001 BramptonDC  41114691 43.6844 -79.7027 0.7624366117582109 -1.3910745377292844 0.1292682275231787 -0.7115076999726074 0.6906855422207024
# Y004 Barrie  8415218 44.3404 -79.6776 0.7738859716512937 -1.3906364600870338 0.12815445555351732 -0.703624623041358 0.6989197560318986
# Y005 Hamilton  8142142 43.2429 -79.8086 0.7547309831106559 -1.3929228414071464 0.1288908053600468 -0.7169624232597502 0.6850927265174731
# Y006 Kingston  4297028 44.274197 -76.439718 0.7727305113265959 -1.3341247583959748 0.16788097708598454 -0.6960476093390254 0.6980929043229723
# Y007 London  10456162 42.9227 -81.1989 0.74914243884577 -1.4171881539976237 0.11204131285450714 -0.7236509556128846 0.6810110415069622
# Y010 Sudbury  2798484 46.4733 -81.0254 0.8111120992670808 -1.4141600077454135 0.10743368859022549 -0.6802612733367616 0.7250535170276372
# Y024 Ottawa  7861575 45.3865 -75.6075 0.7921438609564063 -1.3195998142016128 0.17457103386500575 -0.6802789583795184 0.7118605853124476
# Y053 Toronto  69746509 43.7481 -79.6204 0.7635483864917313 -1.3896381317548931 0.13015167789618487 -0.7105655241208265 0.6914891009059383
# Y054 Thunder Bay  1074646 48.3774 -89.2997 0.8443449135543049 -1.5585737860431803 0.008118267642374334 -0.6641715122267707 0.7475361503478553
# 153906455
# 0.13056654251744432 -0.708837778727297 0.6928570808281556
# -1.3886400751308652 0.7207625257850245 0.765660306831652
# 43.86910412214529 -79.56321556772812

# %% [markdown]
# ### Plotting Map

# %%
fig = px.scatter_geo(sites_data, lon=" Longitude", lat=" Latitude", 
                    projection="natural earth",
                    hover_name = "SiteNumber",
                    hover_data = {" SiteName": True,  
                                  " Volume":True                                                                            
                                    }
                    )

fig.update_traces(marker=dict(size=15, color="red"))

# fit the map to surround the points
fig.update_geos(fitbounds="locations", showcountries = True)

fig.update_geos(
  resolution=50,
  showcoastlines=True, coastlinecolor="RebeccaPurple",
  showland=True, landcolor="LightGreen",
  showocean=True, oceancolor="LightBlue",
  showlakes=True, lakecolor="Blue",
  showrivers=True, rivercolor="Blue"
)


fig.add_scattergeo(lat = [43.86910412214529,0]
                      ,lon = [-79.56321556772812,0]
                      ,hoverinfo = 'none'
                      ,marker_size = 30
                      ,marker_color = 'rgb(65, 105, 225)' # blue
                      ,marker_symbol = 'star'
                      ,showlegend = False
                     )

fig.update_layout(title = 'Center of Gravity for Coke Canada Central Volume')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="2b75b75c-20e9-4f86-bd5c-900a1b56f725" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2b75b75c-20e9-4f86-bd5c-900a1b56f725")) {                    Plotly.newPlot(                        "2b75b75c-20e9-4f86-bd5c-900a1b56f725",                        [{"customdata":[["BramptonDC",41114691],["Barrie",8415218],["Hamilton",8142142],["Kingston",4297028],["London",10456162],["Sudbury",2798484],["Ottawa",7861575],["Toronto",69746509],["Thunder Bay",1074646]],"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br> Latitude=%{lat}<br> Longitude=%{lon}<br> SiteName=%{customdata[0]}<br> Volume=%{customdata[1]}<extra></extra>","hovertext":["Y001","Y004","Y005","Y006","Y007","Y010","Y024","Y053","Y054"],"lat":[43.6844,44.3404,43.2429,44.274197,42.9227,46.4733,45.3865,43.7481,48.3774],"legendgroup":"","lon":[-79.7027,-79.6776,-79.8086,-76.439718,-81.1989,-81.0254,-75.6075,-79.6204,-89.2997],"marker":{"color":"red","symbol":"circle","size":15},"mode":"markers","name":"","showlegend":false,"type":"scattergeo"},{"hoverinfo":"none","lat":[43.86910412214529,0],"lon":[-79.56321556772812,0],"marker":{"color":"rgb(65, 105, 225)","size":30,"symbol":"star"},"showlegend":false,"type":"scattergeo"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111 ...
